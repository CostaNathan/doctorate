# %% [markdown]
# <a href="https://colab.research.google.com/github/CostaNathan/doctorate/blob/Modelos-de-dispers%C3%A3o-e-qualidade-da-%C3%A1gua/od-dbo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Material que pode ajudar: <http://www.lemma.ufpr.br/wiki/images/4/41/Tx752-emcurso.pdf>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
def odes(x, t):
    global Os

    kd = 0.2
    ka = 0.3

    L = x[0]
    O = x[1]
    D = x[2]

    dLdt = - kd * L
    dOdt = - kd * L + ka * (Os - O)
    dDdt = - kd * L - ka * D

    return dLdt, dOdt, dDdt


L0 = 20; O0 = 7; Os = 9; D0 = Os - O0

x0 = [L0, O0, D0]

t = np.linspace(0, 50, 100)

x = odeint(odes, x0, t)

L = x[:, 0]
O = x[:, 1]
D = x[:, 2]

# for i in range(len(D)): # Será que é correto fazer isso? O que explica um déficit negativo?
#   if D[i] < 0:
#     D[i] = 0

plt.figure(dpi=100)
plt.title('DO-BOD model')
plt.plot(t, L, label='BOD')
plt.plot(t, O, label='DO')
plt.plot(t, D, label='Déficit')
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.legend(loc='best')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint


def odes(x, t):
    global Os

    kd = 0.2
    ka = 0.3

    L = x[0]
    O = x[1]
    D = x[2]

    dLdt = -kd * L
    dOdt = -kd * L + ka * (Os - O)
    dDdt = -kd * L - ka * D

    return dLdt, dOdt, dDdt


L0 = 20
O0 = 7
Os = 9
D0 = Os - O0

x0 = [L0, O0, D0]

t = np.linspace(0, 50, 100)

x = odeint(odes, x0, t)

L = x[:, 0]
O = x[:, 1]
D = x[:, 2]

# for i in range(len(D)): # Será que é correto fazer isso? O que explica um déficit negativo?
#   if D[i] < 0:
#     D[i] = 0

plt.figure(dpi=100)
plt.title("DO-BOD model")
plt.plot(t, L, label="BOD")
plt.plot(t, O, label="DO")
plt.plot(t, D, label="Déficit")
plt.xlabel("Time")
plt.ylabel("Concentration")
plt.legend(loc="best")
plt.show()
