# %% [markdown]
# <a href="https://colab.research.google.com/github/CostaNathan/doctorate/blob/Modelos-de-dispers%C3%A3o-e-qualidade-da-%C3%A1gua/Ciclo_do_f%C3%B3sforo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (Chapra, 1997; Bowie, 1985; Delft3D waq manual, Limnotech, 2012) O material orgânico e dissolvido presente na coluna da água proveniente de diatomáceas é composto de proteínas, polissacarídeos, lipídeos e ácidos orgânicos. Essas substâncias contém formas orgânicas de nutrientes como nitrogênio, fósforo e enxofre.
#
# O fosforo inorgânico é formado a partir do fósforo orgânico disponível durante a decomposição de matéria orgânica natural, a qual corresponde à matéria orgânica de fitoplâncton e outros produtores primários morrem.
#
# A partir das referências utilizadas definiu-se o sistema para o fósforo orgânico e inorgânico como:
#
# Fósforo orgânico (fosfato total - fosfato reativo = fosfato particulado e fosfato orgânico dissolvido) = $\frac{dP_{org}}{dt}=∑R=$ morte de fitoplâncton + excreção fitoplâncton - mineralização - sedimentação
#
# \begin{equation}
# \frac{dP_{org}}{dt}= r_{pa}k_{ra}f_{op}α + r_{pa}k_{ra}f_{op}α - k_{mineral}P_{org}
# \end{equation}
#
# Onde
#
# $k_{mineral} = k_{mineral,20}θ^{(T-20)}\frac{α}{α+k_{mineral,s}}$ = 0.001 a 0.8 ($d^{-1}$) (Bowie et al., 1985)
#
# $r_{pa}=$relação fósforo - clorofila-α = 0,5 a 1 gP/gChlA (Bowie et al., 1985)
#
# $f_{op}=$ Fração de morte e respiração de fitoplâncton reciclada para fósforo orgânico = 0.1 a 0.9 (Wasp6)
#
# Fósforo inorgânico (ortofosfato) = $\frac{dP_{inorg}}{dt}=∑R=$ morte de fitoplâncton + respiração fitoplâncton - mineralização - sedimentação + precipitação dos íons fosfato
#
# \begin{equation}
# \frac{dP_{inorg}}{dt}=  r_{pa}k_{ra}(1-f_{op})P_{org} + r_{pa}k_{ra}(1-f_{op})P_{org} + k_{mineral}P_{org} - k_{prec}P_{inorg}
# \end{equation}
#
# Onde
#
# $k_{prec}=$ Taxa de precipitação de ortofosfato pela altura da coluna de água = $\frac{v_{sed}}{H}$
