# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# def dominio ():

df = pd.read_excel('https://github.com/CostaNathan/doctorate/blob/74c3595083b7a9867aa4b35ff148045c9db0cc0b/Trabalho_3/Arquivos_base/dominio_1_corrigido.xlsx?raw=true')
# Out:
#      dx/ dt->    0_elev     0_vel    1_elev     1_vel    2_elev     2_vel  \
# 0           0 -1.049971 -0.969095 -0.851404 -0.902726 -0.468751 -0.610231
# 1         100 -1.163807 -0.969480 -0.941841 -0.903345 -0.518386 -0.611019
# 2         200 -1.348247 -0.954068 -1.097263 -0.892934 -0.608142 -0.607163
# 3         300 -1.463375 -0.956243 -1.193637 -0.894845 -0.667914 -0.608393
# 4         400 -1.767618 -0.944460 -1.447629 -0.888148 -0.813005 -0.607209
# ..        ...       ...       ...       ...       ...       ...       ...
# 112     96900 -0.021900  0.434451 -0.054160  0.255018 -0.024032  0.142130
# 113     97900 -0.017160  0.435860 -0.041616  0.253608 -0.018908  0.142082
# 114     98900 -0.012488  0.436991 -0.029031  0.252485 -0.013799  0.142034
# 115     99900 -0.007921  0.437547 -0.016285  0.251818 -0.008707  0.142016
# 116    100900 -0.003380  0.437833 -0.003528  0.251546 -0.003621  0.142002
#
#        3_elev     3_vel    4_elev  ...    9_elev     9_vel   10_elev  \
# ...
